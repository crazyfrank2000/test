# %% [markdown]
# # 数据可视化

# %%
import numpy as np
import pandas as pd
# import seaborn as sns; 
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. 可视化数据准备

# %%
a = np.random.randn(30, 2)
a.round(2)
# Out:
# array([[-0.26, -0.34],
#        [ 0.14, -1.22],
#        [ 1.34, -1.43],
#        [ 0.14,  1.55],
#        [ 0.08, -0.18],
#        [ 0.42,  1.34],
#        [ 0.88,  0.89],
#        [ 1.43, -1.18],
#        [ 0.8 ,  1.27],
#        [-0.73, -0.17],
#        [ 0.37,  1.59],
#        [-1.19,  0.5 ],
#        [-0.98, -0.22],
#        [-0.38,  0.78],
#        [-0.58, -1.17],
#        [-1.29, -0.08],
#        [-0.22, -0.92],
#        [-1.5 , -1.15],
#        [-0.73,  0.6 ],
#        [ 0.48,  0.83],
#        [-0.31, -0.57],
#        [-0.99, -0.69],
#        [-0.22, -0.73],
#        [ 0.41,  0.13],
#        [ 0.06,  0.6 ],
#        [-0.56,  0.69],
#        [-0.09,  1.93],
#        [-0.87,  0.29],
#        [-0.7 , -0.25],
#        [-0.08,  0.89]])

# %%
df = pd.DataFrame(a)                          #通过ndarray来构建DataFrame
df.head()
# Out:
#           0         1
# 0 -0.256721 -0.335640
# 1  0.142871 -1.219490
# 2  1.336394 -1.432136
# 3  0.143160  1.554373
# 4  0.084173 -0.180712

# %%
df.columns = ['Data1', 'Data2']
df.head()
# Out:
#       Data1     Data2
# 0 -0.256721 -0.335640
# 1  0.142871 -1.219490
# 2  1.336394 -1.432136
# 3  0.143160  1.554373
# 4  0.084173 -0.180712

# %%
dates = pd.date_range('2017-1-1', periods = len(a), freq='D')         #时间日期的生成；

# %%
df.index = dates
df.head()
# Out:
#                Data1     Data2
# 2017-01-01 -0.256721 -0.335640
# 2017-01-02  0.142871 -1.219490
# 2017-01-03  1.336394 -1.432136
# 2017-01-04  0.143160  1.554373
# 2017-01-05  0.084173 -0.180712

# %% [markdown]
# ### 2. Pandas内置图形可视化

# %% [markdown]
# #### 2.1 基础图形可视化

# %%
df.plot()          # DataFrame整体可视化；

# %%
df.plot(figsize= (8, 6), title  = 'Random numbers')

# %%
import seaborn as sns; 
df.plot()

# %%
df['Data2'].plot(figsize = (8,5), ylim = [np.min(df.Data2) * 1.2, np.m(df.Data2) * 1.2])          #也可以单独绘制某一个Series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b49ec3329722> in <module>()
# ----> 1 df['Data2'].plot(figsize = (8,5), ylim = [np.min(df.Data2) * 1.2, np.m(df.Data2) * 1.2])          #也可以单独绘制某一个Series
#
# AttributeError: 'module' object has no attribute 'm'

# %%
df[['Data1','Data2']].plot(subplots=True,figsize = (8, 6));     #子图；

# %%
df.hist(figsize = (9,4), bins = 12)             #直方图；
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0DD9D870>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0DE6F930>]], dtype=object)

# %%
df.plot(x = 'Data1',y = 'Data2', kind='scatter',figsize = (8,6), title = 'Scatter plot')         #散点图；画出股价相关性；kind

# %%
df.cumsum().plot(figsize = (8,6))

# %%
df.plot(style=['o', 'm--'],figsize = (8,6))           #颜色和样式都可以个性化修改；

# %%
df['Data2'] = df['Data2'] * 100

# %%
df.head()

# %%
df.plot(figsize=(10, 5),secondary_y = 'Data2', style = '--')          # 解决方案：,secondary_y='Data2'

# %% [markdown]
# #### 2.2 数据选择及可视化

# %%
data = np.random.standard_normal((10000, 2))

# %%
df = pd.DataFrame(data, columns=['Data1', 'Data2'])
df.head()

# %%
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']    # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False     # 解决保存图像是负号'-'显示为方块的问题
df[(df.Data1 > 2) & (df.Data2 < -2)].plot(x='Data1', y='Data2', kind='scatter',title = 'Outlier图')       #scatter是plot里面的内置参数；

# %% [markdown]
# ### 3. Matplotlib图形绘制

# %% [markdown]
# #### 3.1 Matplotlib基础图形绘制

# %% [markdown]
# **Plt常用功能：**
#
# --plt.plot() : 绘制图形；x轴和y轴；
#
# --plt.show()：图形显示；IDE,pycharm是一定要加这句话的；
#
# --plt.figure()：生成图形对象，确定图片大小；
#
# --plt.title()：确定图片标题；
#
# --plt.xlabel()：确定图片x轴的名字；
#
# --plt.legend()：显示图例；
#
# --plt.scatter()：绘制散点图；
#
# --plt.grid(True)：出现网格；
#
# --plt.subplot()：绘制子图；
#
# --plt.bar()：绘制柱状图；

# %% [markdown]
# #### 3.1.1 添加图例和设置线型及颜色

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot([1,2,3,4],[2,4,6,8],lw = 1.0)
plt.ylabel('Numbers')
plt.xlabel('Numbers')
# plt.show()

# %%
import seaborn as sns
plt.plot([1,2,3,4],[2,4,6,8], 'r--',linewidth=1.0, label = 'Line',)    #'ro',plt.ylim(0,10)
plt.ylabel('Numbers')
plt.legend()     #显示图例；
plt.ylim(0,10)
# plt.show()

# %% [markdown]
# #### 3.1.2 一次绘制多条线并设置线形及颜色

# %%
t = np.arange(0, 3, 0.2) 

plt.plot(t, t, 'r--',
         t, t ** 2, 'b', 
         t, t ** 3, 'm .')

# %% [markdown]
# #### 3.1.3 调整图片和坐标值大小

# %%
np.random.seed(10)
y = np.random.standard_normal(20)

# %%
x = range(len(y))
plt.figure(figsize =(8,6))    #确定图像大小
plt.plot(x, y)

# %%
plt.figure(figsize =(8,6))    #确定图像大小
plt.plot(y)           #x是序号，默认；

# %%
plt.figure(figsize =(8,6))
plt.plot(y.cumsum())

# %% [markdown]
# #### 3.1.4 分别编写绘图命令，输出在同一张图内

# %%
from matplotlib import style
style.use('ggplot')           #matplotlib下的一种style；

x = [1,5,10]
y = [2,8,16]

x2 = [10,5,1]
y2 = [9,20,7]

# 分别编写绘图命令，输出在同一张图内
plt.figure(figsize = (8,6))    #生成图片对象；
plt.plot(x,y,linewidth=1, label = 'line1')     #这里的label是图例；
plt.plot(x2,y2,linewidth=1, label = 'line2')

plt.title('Two Line Plot')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.legend()

# %% [markdown]
# #### 3.2 绘制散点图

# %%
x = [1,5,10,10,5,4,6,9,12]
y = [2,8,16,12,10,7,8,13,15]

plt.figure(figsize = (8,6))
plt.scatter(x,y,color = 'r')    #plt.scatter()
plt.title('Scatter plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.grid(True)

# %% [markdown]
# **3.3 Matplotlib两维图形绘制**

# %%
np.random.seed(2000)
y = np.random.randn(20, 2).cumsum(axis=0)
y

# %%
plt.figure(figsize=(7, 4))
plt.plot(y, lw=1.5)

plt.grid(True)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('2 dimensions Plot')

# %%
plt.figure(figsize=(7, 4))
plt.plot(y[:, 0], lw=1.5, label='line1')
plt.plot(y[:, 1], lw=1.5, label='line2')

plt.grid(True)
plt.legend(loc=0)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('2 dimensions Plot')

# %%
y[:, 0] = y[:, 0] * 100

plt.figure(figsize=(8, 6))
plt.plot(y[:, 0], lw=1.5, label='Line1')
plt.plot(y[:, 1], lw=1.5, label='Line2')

plt.grid(True)
plt.legend()
plt.xlabel('index')
plt.ylabel('value')
plt.title('2 dimensions Plot')

# %%
fig1,ax = plt.subplots(figsize = (10,6))      #plt.subplot会返回一个figure对象和一个坐标轴对象；

plt.plot(y[:, 0], lw=1.5, label='line1')
plt.grid(True)
plt.legend(loc=8)
plt.xlabel('x')
plt.ylabel('y')
plt.title('plot')

ax2 = ax.twinx()       #复制上一张子图的横坐标轴；
plt.plot(y[:, 1], 'g', lw=1.5, label='line2')
plt.legend()
plt.ylabel('y2')

# %% [markdown]
# #### 3.4 Matplotlib子图绘制

# %%
plt.figure(figsize=(8,6))
plt.subplot(211)
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.legend(loc=0)
plt.ylabel('Value')
plt.title('Sub Plot')

plt.subplot(212)
plt.plot(y[:, 1], 'm', lw=1.5, label='2nd')
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')

# %%
plt.figure(figsize=(12, 5))

plt.subplot(121)
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.legend()
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('1st Data Set')

plt.subplot(122)
plt.bar(np.arange(len(y)), y[:, 1], width=0.5,
        color='c', label='2nd')
plt.legend()
plt.xlabel('Index')
plt.title('2nd Data Set')

# %% [markdown]
# **3.5 其他图形**

# %%
y = np.random.standard_normal((100, 2))

# %%
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']    # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False     # 解决保存图像是负号'-'显示为方块的问题

plt.figure(figsize=(7, 5))
plt.plot(y[:, 0], y[:, 1],'c.')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('散点图')                     #散点图在分析股价的相关性的时候用的很多；              #散点图在分析股价的相关性的时候用的很多；

# %% [markdown]
# ### 4. Seaborn

# %% [markdown]
# Example参考网址：https://seaborn.pydata.org/examples/index.html

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# cmap = sns.light_palette("#2ecc71", as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,  cmap=cmap, vmax=.3, linewidths=.5)

# %%
import numpy as np, pandas as pd; np.random.seed(0)
import seaborn as sns; sns.set(style="white", color_codes=True)

tips = sns.load_dataset("tips")
g = sns.jointplot(x="total_bill", y="tip", data=tips)

# %%
g = sns.jointplot("total_bill", "tip", data=tips, kind="reg")

# %% [markdown]
# 声明：本资料仅限内部研究和交流使用，切勿外传。
